# %%
import google.generativeai as genai

# %%
genai.configure(api_key = 'AIzaSyABRyoJr3kunqI_uSJ1fF3PM9LvjKNxUlg')

# %%
for m in genai.list_models():
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/aqa

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content('Translate the following sentence to Hawaiian: I like dogs.')
print(response.text)
# Out:
# Aloha nā ʻīlio.

# %%
response = model.generate_content('Give me a Hawaiian proverb about loving one another')

# %%
response.text
# Out:
# '"E ola mau ke aloha, a mau a mau no, a mau a mau loa."\n\nTranslation: "Love lives forever, endures always, and lasts forever and ever."\n\nThis proverb reflects the Hawaiian value of aloha, which encompasses love, compassion, and empathy. It emphasizes the importance of loving one another unconditionally and enduringly, even through difficult times.'
